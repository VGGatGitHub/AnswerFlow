# %% [markdown]
# <a href="https://colab.research.google.com/github/VGGatGitHub/AnswerFlow/blob/master/chatbot_v7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/datasets?search=nq-train
#
# V2: added comads to look at the structure of the train.json file and to assess the %s.
#
# V3: changing the code to do tarining for long_answesrs or short_answers using training_for_long_answer switch.
#
# V4: reading in json file produced from jsonl using jsonl2json.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys 
import os
print(os.getcwd())
# Out:
# /content

# %%
#VGG define the foldre to inspect for files 
path='/content/drive/My Drive/Colab Notebooks/'

# %%
#make sure the file you what is in the correct directory
#some possible files are train.json or train200.json 

for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/My Drive/Colab Notebooks/qa.ipynb
# /content/drive/My Drive/Colab Notebooks/transformer.ipynb
# /content/drive/My Drive/Colab Notebooks/chatbot_transformer.ipynb
# /content/drive/My Drive/Colab Notebooks/chatbot_embed.ipynb
# /content/drive/My Drive/Colab Notebooks/embeddings.ipynb
# /content/drive/My Drive/Colab Notebooks/chatbot_v3.ipynb
# /content/drive/My Drive/Colab Notebooks/text_utils.py
# /content/drive/My Drive/Colab Notebooks/__init__.py
# /content/drive/My Drive/Colab Notebooks/chatbot_v4.ipynb
# /content/drive/My Drive/Colab Notebooks/train8k.json
# /content/drive/My Drive/Colab Notebooks/chatbot_v8.ipynb
# /content/drive/My Drive/Colab Notebooks/chatbot_v7.1.ipynb
# /content/drive/My Drive/Colab Notebooks/__pycache__/text_utils.cpython-36.pyc

# %%
#VGG read in training data
#you may have to adjust the BATCH_SIZE acordingly 
filename='train.json' #or train.json or train200L.json 
filename='train8k.json'

file_to_read=path+filename

# %%
# VGG
# you may need to get the file text_utils.py from 
# https://github.com/VGGatGitHub/natural-questions
#

sys.path.append(os.path.abspath(path))
# from text_utils import *

# got import errors on colab using import code above
import text_utils

# %%
#VGG The cell has been removed since now the data is analized in the jsonl2json.ipynb

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# Install TensorFlow
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0-rc1

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time
import json

# Converts the unicode file to ascii
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())

    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)

    # replacing everything with space except (0-9, a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^0-9a-zA-Z?.!,¿]+", " ", w)

    w = w.rstrip().strip()

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
#VGG make sure the file_to_read has been defined above! 

UNKNOWN = "<UNKNOWN>"
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, SPANISH]
def create_dataset():
    source = []
    target = []
    context = []

    n_short_answers=0 #VGG
    n_long=0
    training_for_long_answer = False #True #False 
    
    with open(file_to_read) as json_file: #VGG
        data = json.load(json_file)

        for nq_doc in data:
            if filename == 'train200L.json':
              doc = simplify_nq_example(nq_doc) #VGG for jsonl formated file
            else:
              doc=nq_doc

            question_text = doc['question_text']
            document_text = doc['document_text'].split()
            long_answer_candidates = doc['long_answer_candidates']
            annotations = doc['annotations'][0]
            
            if annotations['long_answer']['start_token'] < annotations['long_answer']['end_token']:
                
                n_long+=1
                long_answer = " ".join(document_text[annotations['long_answer']['start_token']:
                                                     annotations['long_answer']['end_token']])
                                      
                if len(annotations['short_answers']) > 0:
                    start_token = annotations['short_answers'][0]['start_token']
                    end_token = annotations['short_answers'][0]['end_token']
                    short_answer = " ".join(document_text[start_token:end_token])
                    n_short_answers+=1 #VGG
                else:
                    short_answer = UNKNOWN
                
                #VGG V3
                if training_for_long_answer :
                    short_answer=long_answer #VGG V3 change - make the target to be the long answer instead of the short answer 
                    for posibilities in long_answer_candidates:
                        if posibilities["top_level"]:
                            start_token = posibilities['start_token']
                            end_token = posibilities['end_token']                    
                            posibility = " ".join(document_text[start_token:end_token])
                            context.append(preprocess_sentence(posibility))
                else:
                    context.append(preprocess_sentence(long_answer))
                
                #VGG context = [] #VGG it seems to work better!

                source.append(preprocess_sentence(question_text))
                target.append(preprocess_sentence(short_answer))
#VGG                
        print("Data set of:",len(data)," elements. It contains:",
              n_short_answers,"short answers out of", n_long,
              "possible long answers, short/long rate is {:.0f}%".format(
                  100*n_short_answers/n_long))    
    return target, source, context

# %%
def max_length(tensor):
    return max(len(t) for t in tensor)
    
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)
  tensor = lang_tokenizer.texts_to_sequences(lang)
  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')
  return tensor, lang_tokenizer

def load_dataset():
    # creating cleaned input, output pairs
    targ_lang, inp_lang, context_lang = create_dataset()

    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)
    
    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))
    
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # hidden shape == (batch_size, hidden size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden size)
    # we are doing this to perform addition to calculate the score
    hidden_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(values) + self.W2(hidden_with_time_axis)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights
    
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# Try experimenting with the size of that dataset
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset()

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = max_length(target_tensor), max_length(input_tensor)    

# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 32 #VGG
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 1024
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape

encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)    
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')
    
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)
  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ = tf.multiply(loss_, mask)
  return tf.reduce_mean(loss_)


#VGG uncommented for possible checkpoint saving later 

checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)  

                                 
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))
  variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables))
  return batch_loss
  
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))
    sentence = preprocess_sentence(sentence)

    inputs = [inp_lang.word_index.get(i, 0) for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                           maxlen=max_length_inp,
                                                           padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''
    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    result ='<start> '#VGG 
    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                             dec_hidden,
                                                             enc_out)

        # storing the attention weights to plot later on
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = attention_weights.numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()
        result += targ_lang.index_word[predicted_id] + ' '

        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence, attention_plot

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)
    return result, sentence, attention_plot
# Out:
# Data set of: 1024  elements. It contains: 378 short answers out of 532 possible long answers, short/long rate is 71%

# %%
EPOCHS = 100

#VGG for epoch in range(EPOCHS):
epoch=-1
total_loss=1
total_loss_cut = 0.01 * steps_per_epoch

best_total_loss = sys.maxsize
patience = 14
stop = False
stopping_step = 0

print("\nStarting training of at most {} epochs or if no improvement after {} steps".format(EPOCHS,patience))
#while (epoch < EPOCHS) and (total_loss > total_loss_cut):
while (epoch < EPOCHS) and (stop == False):
  start = time.time()
  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0
  epoch+=1

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch%8 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                     batch,
                                                     batch_loss.numpy()))
  '''
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)
  '''   

  if (total_loss < best_total_loss):
    stopping_step = 0
    best_total_loss = total_loss
  else:
    stopping_step += 1
  if stopping_step >= patience:
    stop = True

  print('Epoch {} Total Loss {:.4f}'.format(epoch + 1, total_loss))
  print('Time taken for this epoch {:.4f} sec\n'.format(time.time() - start))
# Out:
# Starting training of at most 100 epochs or if no improvement after 14 steps
# Epoch 1 Batch 0 Loss 0.2384
# Epoch 1 Batch 8 Loss 0.2878
# Epoch 1 Total Loss 3.3863
# Time taken for this epoch 90.4538 sec
#
# Epoch 2 Batch 0 Loss 0.2023
# Epoch 2 Batch 8 Loss 0.1853
# Epoch 2 Total Loss 2.7454
# Time taken for this epoch 3.8114 sec
#
# Epoch 3 Batch 0 Loss 0.3737
# Epoch 3 Batch 8 Loss 0.2543
# Epoch 3 Total Loss 2.5309
# Time taken for this epoch 3.8224 sec
#
# Epoch 4 Batch 0 Loss 0.2113
# Epoch 4 Batch 8 Loss 0.1995
# Epoch 4 Total Loss 2.3646
# Time taken for this epoch 3.8243 sec
#
# Epoch 5 Batch 0 Loss 0.2808
# Epoch 5 Batch 8 Loss 0.1573
# Epoch 5 Total Loss 2.2241
# Time taken for this epoch 3.8291 sec
#
# Epoch 6 Batch 0 Loss 0.1382
# Epoch 6 Batch 8 Loss 0.1050
# Epoch 6 Total Loss 2.0898
# Time taken for this epoch 3.8530 sec
#
# Epoch 7 Batch 0 Loss 0.1678
# Epoch 7 Batch 8 Loss 0.1126
# Epoch 7 Total Loss 1.9509
# Time taken for this epoch 3.7829 sec
#
# Epoch 8 Batch 0 Loss 0.1129
# Epoch 8 Batch 8 Loss 0.1334
# Epoch 8 Total Loss 1.8610
# Time taken for this epoch 3.9149 sec
#
# Epoch 9 Batch 0 Loss 0.0904
# Epoch 9 Batch 8 Loss 0.0937
# Epoch 9 Total Loss 1.7168
# Time taken for this epoch 3.8193 sec
#
# Epoch 10 Batch 0 Loss 0.1032
# Epoch 10 Batch 8 Loss 0.0976
# Epoch 10 Total Loss 1.5412
# Time taken for this epoch 3.7920 sec
#
# Epoch 11 Batch 0 Loss 0.0990
# Epoch 11 Batch 8 Loss 0.1002
# Epoch 11 Total Loss 1.3847
# Time taken for this epoch 3.8386 sec
#
# Epoch 12 Batch 0 Loss 0.0652
# Epoch 12 Batch 8 Loss 0.0732
# Epoch 12 Total Loss 1.2775
# Time taken for this epoch 3.8108 sec
#
# Epoch 13 Batch 0 Loss 0.1144
# Epoch 13 Batch 8 Loss 0.0895
# Epoch 13 Total Loss 1.1151
# Time taken for this epoch 3.8597 sec
#
# Epoch 14 Batch 0 Loss 0.0772
# Epoch 14 Batch 8 Loss 0.0690
# Epoch 14 Total Loss 0.9853
# Time taken for this epoch 3.8365 sec
#
# Epoch 15 Batch 0 Loss 0.0513
# Epoch 15 Batch 8 Loss 0.0732
# Epoch 15 Total Loss 0.8615
# Time taken for this epoch 3.8115 sec
#
# Epoch 16 Batch 0 Loss 0.0685
# Epoch 16 Batch 8 Loss 0.0925
# Epoch 16 Total Loss 0.8171
# Time taken for this epoch 3.8399 sec
#
# Epoch 17 Batch 0 Loss 0.0504
# Epoch 17 Batch 8 Loss 0.0756
# Epoch 17 Total Loss 0.7349
# Time taken for this epoch 3.8458 sec
#
# Epoch 18 Batch 0 Loss 0.0845
# Epoch 18 Batch 8 Loss 0.0484
# Epoch 18 Total Loss 0.6641
# Time taken for this epoch 3.8433 sec
#
# Epoch 19 Batch 0 Loss 0.0386
# Epoch 19 Batch 8 Loss 0.0654
# Epoch 19 Total Loss 0.6092
# Time taken for this epoch 3.8452 sec
#
# Epoch 20 Batch 0 Loss 0.0738
# Epoch 20 Batch 8 Loss 0.0563
# Epoch 20 Total Loss 0.5645
# Time taken for this epoch 3.7781 sec
#
# Epoch 21 Batch 0 Loss 0.0274
# Epoch 21 Batch 8 Loss 0.0416
# Epoch 21 Total Loss 0.5160
# Time taken for this epoch 3.7942 sec
#
# Epoch 22 Batch 0 Loss 0.0225
# Epoch 22 Batch 8 Loss 0.0367
# Epoch 22 Total Loss 0.4720
# Time taken for this epoch 3.8266 sec
#
# Epoch 23 Batch 0 Loss 0.0268
# Epoch 23 Batch 8 Loss 0.0409
# Epoch 23 Total Loss 0.4153
# Time taken for this epoch 3.8322 sec
#
# Epoch 24 Batch 0 Loss 0.0423
# Epoch 24 Batch 8 Loss 0.0253
# Epoch 24 Total Loss 0.3502
# Time taken for this epoch 3.9101 sec
#
# Epoch 25 Batch 0 Loss 0.0131
# Epoch 25 Batch 8 Loss 0.0165
# Epoch 25 Total Loss 0.3070
# Time taken for this epoch 3.7942 sec
#
# Epoch 26 Batch 0 Loss 0.0181
# Epoch 26 Batch 8 Loss 0.0242
# Epoch 26 Total Loss 0.2818
# Time taken for this epoch 3.8374 sec
#
# Epoch 27 Batch 0 Loss 0.0183
# Epoch 27 Batch 8 Loss 0.0151
# Epoch 27 Total Loss 0.2423
# Time taken for this epoch 3.8096 sec
#
# Epoch 28 Batch 0 Loss 0.0089
# Epoch 28 Batch 8 Loss 0.0132
# Epoch 28 Total Loss 0.1841
# Time taken for this epoch 3.7790 sec
#
# Epoch 29 Batch 0 Loss 0.0141
# Epoch 29 Batch 8 Loss 0.0036
# Epoch 29 Total Loss 0.1481
# Time taken for this epoch 3.8387 sec
#
# Epoch 30 Batch 0 Loss 0.0047
# Epoch 30 Batch 8 Loss 0.0049
# Epoch 30 Total Loss 0.1155
# Time taken for this epoch 3.8241 sec
#
# Epoch 31 Batch 0 Loss 0.0055
# Epoch 31 Batch 8 Loss 0.0261
# Epoch 31 Total Loss 0.0982
# Time taken for this epoch 3.7998 sec
#
# Epoch 32 Batch 0 Loss 0.0043
# Epoch 32 Batch 8 Loss 0.0060
# Epoch 32 Total Loss 0.0852
# Time taken for this epoch 3.8648 sec
#
# Epoch 33 Batch 0 Loss 0.0033
# Epoch 33 Batch 8 Loss 0.0044
# Epoch 33 Total Loss 0.0692
# Time taken for this epoch 3.8364 sec
#
# Epoch 34 Batch 0 Loss 0.0025
# Epoch 34 Batch 8 Loss 0.0010
# Epoch 34 Total Loss 0.0842
# Time taken for this epoch 3.8771 sec
#
# Epoch 35 Batch 0 Loss 0.0024
# Epoch 35 Batch 8 Loss 0.0029
# Epoch 35 Total Loss 0.0872
# Time taken for this epoch 3.8004 sec
#
# Epoch 36 Batch 0 Loss 0.0033
# Epoch 36 Batch 8 Loss 0.0064
# Epoch 36 Total Loss 0.0912
# Time taken for this epoch 3.8582 sec
#
# Epoch 37 Batch 0 Loss 0.0050
# Epoch 37 Batch 8 Loss 0.0094
# Epoch 37 Total Loss 0.0772
# Time taken for this epoch 3.8796 sec
#
# Epoch 38 Batch 0 Loss 0.0072
# Epoch 38 Batch 8 Loss 0.0022
# Epoch 38 Total Loss 0.0774
# Time taken for this epoch 3.8607 sec
#
# Epoch 39 Batch 0 Loss 0.0047
# Epoch 39 Batch 8 Loss 0.0012
# Epoch 39 Total Loss 0.0796
# Time taken for this epoch 3.8191 sec
#
# Epoch 40 Batch 0 Loss 0.0030
# Epoch 40 Batch 8 Loss 0.0025
# Epoch 40 Total Loss 0.0716
# Time taken for this epoch 3.8248 sec
#
# Epoch 41 Batch 0 Loss 0.0023
# Epoch 41 Batch 8 Loss 0.0029
# Epoch 41 Total Loss 0.0616
# Time taken for this epoch 3.8307 sec
#
# Epoch 42 Batch 0 Loss 0.0025
# Epoch 42 Batch 8 Loss 0.0074
# Epoch 42 Total Loss 0.0625
# Time taken for this epoch 3.8137 sec
#
# Epoch 43 Batch 0 Loss 0.0050
# Epoch 43 Batch 8 Loss 0.0020
# Epoch 43 Total Loss 0.0518
# Time taken for this epoch 3.8188 sec
#
# Epoch 44 Batch 0 Loss 0.0006
# Epoch 44 Batch 8 Loss 0.0012
# Epoch 44 Total Loss 0.0474
# Time taken for this epoch 3.8226 sec
#
# Epoch 45 Batch 0 Loss 0.0017
# Epoch 45 Batch 8 Loss 0.0010
# Epoch 45 Total Loss 0.0460
# Time taken for this epoch 3.8258 sec
#
# Epoch 46 Batch 0 Loss 0.0158
# Epoch 46 Batch 8 Loss 0.0017
# Epoch 46 Total Loss 0.0395
# Time taken for this epoch 3.7909 sec
#
# Epoch 47 Batch 0 Loss 0.0024
# Epoch 47 Batch 8 Loss 0.0058
# Epoch 47 Total Loss 0.0298
# Time taken for this epoch 3.8397 sec
#
# Epoch 48 Batch 0 Loss 0.0004
# Epoch 48 Batch 8 Loss 0.0035
# Epoch 48 Total Loss 0.0320
# Time taken for this epoch 3.8203 sec
#
# Epoch 49 Batch 0 Loss 0.0005
# Epoch 49 Batch 8 Loss 0.0020
# Epoch 49 Total Loss 0.0269
# Time taken for this epoch 3.8154 sec
#
# Epoch 50 Batch 0 Loss 0.0002
# Epoch 50 Batch 8 Loss 0.0011
# Epoch 50 Total Loss 0.0244
# Time taken for this epoch 3.7780 sec
#
# Epoch 51 Batch 0 Loss 0.0003
# Epoch 51 Batch 8 Loss 0.0028
# Epoch 51 Total Loss 0.0274
# Time taken for this epoch 3.7707 sec
#
# Epoch 52 Batch 0 Loss 0.0007
# Epoch 52 Batch 8 Loss 0.0027
# Epoch 52 Total Loss 0.0240
# Time taken for this epoch 3.8262 sec
#
# Epoch 53 Batch 0 Loss 0.0003
# Epoch 53 Batch 8 Loss 0.0022
# Epoch 53 Total Loss 0.0233
# Time taken for this epoch 3.8404 sec
#
# Epoch 54 Batch 0 Loss 0.0003
# Epoch 54 Batch 8 Loss 0.0002
# Epoch 54 Total Loss 0.0176
# Time taken for this epoch 3.8006 sec
#
# Epoch 55 Batch 0 Loss 0.0001
# Epoch 55 Batch 8 Loss 0.0003
# Epoch 55 Total Loss 0.0154
# Time taken for this epoch 3.8695 sec
#
# Epoch 56 Batch 0 Loss 0.0013
# Epoch 56 Batch 8 Loss 0.0015
# Epoch 56 Total Loss 0.0142
# Time taken for this epoch 3.7989 sec
#
# Epoch 57 Batch 0 Loss 0.0037
# Epoch 57 Batch 8 Loss 0.0004
# Epoch 57 Total Loss 0.0195
# Time taken for this epoch 3.8466 sec
#
# Epoch 58 Batch 0 Loss 0.0002
# Epoch 58 Batch 8 Loss 0.0017
# Epoch 58 Total Loss 0.0193
# Time taken for this epoch 3.8538 sec
#
# Epoch 59 Batch 0 Loss 0.0003
# Epoch 59 Batch 8 Loss 0.0002
# Epoch 59 Total Loss 0.0218
# Time taken for this epoch 3.7909 sec
#
# Epoch 60 Batch 0 Loss 0.0003
# Epoch 60 Batch 8 Loss 0.0067
# Epoch 60 Total Loss 0.0298
# Time taken for this epoch 3.8628 sec
#
# Epoch 61 Batch 0 Loss 0.0017
# Epoch 61 Batch 8 Loss 0.0006
# Epoch 61 Total Loss 0.0386
# Time taken for this epoch 3.9055 sec
#
# Epoch 62 Batch 0 Loss 0.0009
# Epoch 62 Batch 8 Loss 0.0055
# Epoch 62 Total Loss 0.0382
# Time taken for this epoch 3.7978 sec
#
# Epoch 63 Batch 0 Loss 0.0007
# Epoch 63 Batch 8 Loss 0.0022
# Epoch 63 Total Loss 0.0415
# Time taken for this epoch 3.8692 sec
#
# Epoch 64 Batch 0 Loss 0.0077
# Epoch 64 Batch 8 Loss 0.0035
# Epoch 64 Total Loss 0.0787
# Time taken for this epoch 3.9037 sec
#
# Epoch 65 Batch 0 Loss 0.0030
# Epoch 65 Batch 8 Loss 0.0051
# Epoch 65 Total Loss 0.0823
# Time taken for this epoch 3.8531 sec
#
# Epoch 66 Batch 0 Loss 0.0116
# Epoch 66 Batch 8 Loss 0.0031
# Epoch 66 Total Loss 0.0658
# Time taken for this epoch 3.8392 sec
#
# Epoch 67 Batch 0 Loss 0.0027
# Epoch 67 Batch 8 Loss 0.0032
# Epoch 67 Total Loss 0.0837
# Time taken for this epoch 3.8889 sec
#
# Epoch 68 Batch 0 Loss 0.0045
# Epoch 68 Batch 8 Loss 0.0047
# Epoch 68 Total Loss 0.0884
# Time taken for this epoch 3.8872 sec
#
# Epoch 69 Batch 0 Loss 0.0012
# Epoch 69 Batch 8 Loss 0.0041
# Epoch 69 Total Loss 0.0698
# Time taken for this epoch 3.8940 sec
#
# Epoch 70 Batch 0 Loss 0.0009
# Epoch 70 Batch 8 Loss 0.0034
# Epoch 70 Total Loss 0.0668
# Time taken for this epoch 3.8441 sec

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(1, 1, 1)
    ax.matshow(attention, cmap='viridis')
    fontdict = {'fontsize': 14}
    ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
    ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    plt.show()

def ask(sentence):
    result, sentence1, attention_plot = evaluate(sentence)
    print('\nQuestion: %s' % (sentence))
    print('Predicted answer: {}'.format(result))
    return result

def show_attention_plot(sentence):
  result, sentence1, attention_plot = evaluate(sentence)
  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

def is_it_known(sentence):
    result, sentence, attention_plot = evaluate(sentence)
    if result.split() != ['<start>', 'unknown', '<end>']: return True
    return False

# %%
ask('which is the most common use of opt-in e-mail marketing')    
ask('most common use of opt-in e-mail marketing')
ask('how did I meet your mother')
ask('who is your mother')
# Out:
# Question: which is the most common use of opt-in e-mail marketing
# Predicted answer: <start> a newsletter sent to an advertising firm s customers <end>
#
# Question: most common use of opt-in e-mail marketing
# Predicted answer: <start> a newsletter sent to an advertising firm s customers <end>
#
# Question: how did I meet your mother
# Predicted answer: <start> approximately 4 , 400 <end>
#
# Question: who is your mother
# Predicted answer: <start> four <end>
# '<start> four <end> '

# %%
show_attention_plot("which is the most common use of opt in e mail marketing")

# %%
show_attention_plot("who plays young flo in the progressive commercials")

# %%
target, source, context = create_dataset()
print("\ngoing over all the questions and selecting those with answers ... \n")
n_answers=0
i=-1
n_correct=0
for question_text in source:
    i+=1
    if is_it_known(question_text):
        n_answers+=1
        AFanswer=ask(question_text)
        if AFanswer.split() == target[i].split(): 
          n_correct+=1
        else:
          print("The answer was:",target[i])
          #print(question_text)
          #print(AFanswer.split())
          #print(target[i].split())
          print('\n')

print("\n{} answers out of {} possible, rate is {:.0f}%".format(n_answers,len(source),100*n_answers/len(source)))
if n_answers > 0:
  print("At least {} correct answers out of {} possible, rate is {:.0f}%\n".format(n_correct,n_answers,100*n_correct/n_answers))
# Out:
# Data set of: 1024  elements. It contains: 378 short answers out of 532 possible long answers, short/long rate is 71%
#
# going over all the questions and selecting those with answers ...
#
#
# Question: <start> which is the most common use of opt in e mail marketing <end>
# Predicted answer: <start> a newsletter sent to an advertising firm s customers <end>
#
# Question: <start> how i . met your mother who is the mother <end>
# Predicted answer: <start> four <end>
# The answer was: <start> tracy mcconnell <end>
#
#
#
# Question: <start> who had the most wins in the nfl <end>
# Predicted answer: <start> tom <end>
# The answer was: <start> tom brady <end>
#
#
#
# Question: <start> who played mantis guardians of the galaxy 2 <end>
# Predicted answer: <start> john maynard keynes <end>
# The answer was: <start> pom klementieff <end>
#
#
#
# Question: <start> who is deputy cm of j and k <end>
# Predicted answer: <start> john f . the fighting tigers of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules . hyperlipidemia is the concentration of elevated or bound to other molecules .
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> the nashville sound brought a polished and cosmopolitan sound to country music by <end>
# Predicted answer: <start> the use of lush string arrangements with a real orchestra and often , background vocals provided by a choir <end>
#
# Question: <start> what channel is the premier league on in france <end>
# Predicted answer: <start> sfr sport <end>
#
# Question: <start> god s not dead a light in the darkness release date <end>
# Predicted answer: <start> march 30 , 2018 <end>
#
# Question: <start> when do they pull the powerball numbers 2016 <end>
# Predicted answer: <start> every wednesday and saturday evening at 10 59 p . m . eastern time <end>
#
# Question: <start> when do the eclipse supposed to take place <end>
# Predicted answer: <start> august 21 , 2017 <end>
#
# Question: <start> what is the name of the sea surrounding dubai <end>
# Predicted answer: <start> persian gulf <end>
#
# Question: <start> who holds the nba record for most points in a career <end>
# Predicted answer: <start> kareem abdul jabbar <end>
#
# Question: <start> when did the new maze runner movie come out <end>
# Predicted answer: <start> january 26 , 2018 <end>
#
# Question: <start> how many players on a box lacrosse team <end>
# Predicted answer: <start> six <end>
#
# Question: <start> where are the upcoming olympics to be held <end>
# Predicted answer: <start> tokyo for the 2020 summer olympics <end>
#
# Question: <start> when did the nba 3 second rule start <end>
# Predicted answer: <start> 1936 <end>
#
# Question: <start> where does the phrase bob s your uncle come from <end>
# Predicted answer: <start> march 30 , and shrink the appearance of pores <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who won so you think you can dance 2016 <end>
# Predicted answer: <start> leon kida burns <end>
#
# Question: <start> who plays norman bates in the tv show <end>
# Predicted answer: <start> freddie highmore <end>
#
# Question: <start> when did usa start driving on the right <end>
# Predicted answer: <start> late 1700s <end>
#
# Question: <start> name some components of the central nervous system cns <end>
# Predicted answer: <start> brain <end>
#
# Question: <start> who s the director of the price is right <end>
# Predicted answer: <start> adam sandler <end>
#
# Question: <start> bridge on the river kwai fact or fiction <end>
# Predicted answer: <start> fiction <end>
#
# Question: <start> why did argentina attack the falklands malvinas islands <end>
# Predicted answer: <start> an attempt to establish the sovereignty it had claimed over them <end>
#
# Question: <start> how long does it take for the moon to go around earth <end>
# Predicted answer: <start> july 2018 <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who is the prime minister of republic of mauritius <end>
# Predicted answer: <start> pravind jugnauth <end>
#
# Question: <start> what teams are in the fa cup final <end>
# Predicted answer: <start> manchester united <end>
#
# Question: <start> where is a midsummer night s dream set <end>
# Predicted answer: <start> in the woodland and in the realm of fairyland <end>
#
# Question: <start> who is the first person who went to moon <end>
# Predicted answer: <start> john f . the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or abnormal levels of the quad cities community of elevated or
# The answer was: <start> neil alden armstrong <end>
#
#
#
# Question: <start> when did the first lego movie come out <end>
# Predicted answer: <start> the lego movie <end>
#
# Question: <start> are pure metals made of atoms or ions <end>
# Predicted answer: <start> atoms <end>
#
# Question: <start> what episode in victorious is give it up <end>
# Predicted answer: <start> freak the freak out <end>
#
# Question: <start> movement of molecules across a membrane powered by atp <end>
# Predicted answer: <start> primary active transport <end>
#
# Question: <start> who sold manhattan to the dutch in 1626 <end>
# Predicted answer: <start> seyseys , chief of the canarsees <end>
#
# Question: <start> what year did the movie deuces come out <end>
# Predicted answer: <start> late down , 2018 <end>
# The answer was: <start> 2017 <end>
#
#
#
# Question: <start> who is the present sport minister of india <end>
# Predicted answer: <start> rajyavardhan singh rathore <end>
#
# Question: <start> who has the most followers on instagram in the world <end>
# Predicted answer: <start> instagram <end>
#
# Question: <start> where was life or something like it filmed <end>
# Predicted answer: <start> seattle , washington <end>
#
# Question: <start> the highest post in police department of karnataka state is <end>
# Predicted answer: <start> the director general and inspector general of police dg igp <end>
#
# Question: <start> what is the worth of the catholic church <end>
# Predicted answer: <start> 140 billion <end>
#
# Question: <start> where is the best farming soil in the us and where did all the dirt come from <end>
# Predicted answer: <start> the black dirt region <end>
#
# Question: <start> the pair of hand drums used in indian classical music is called <end>
# Predicted answer: <start> tabla <end>
#
# Question: <start> where does the term petty officer come from <end>
# Predicted answer: <start> age of sail <end>
#
# Question: <start> where is israel located on the world map <end>
# Predicted answer: <start> the middle east , and shrink the southeastern shore of the gdp <end>
# The answer was: <start> the middle east , on the southeastern shore of the mediterranean sea and the northern shore of the red sea <end>
#
#
#
# Question: <start> who played smiley in tinker tailor soldier spy <end>
# Predicted answer: <start> gary oldman <end>
#
# Question: <start> when does brennan get pregnant the first time <end>
# Predicted answer: <start> season six finale <end>
#
# Question: <start> when did season 2 of handmaid s tale start <end>
# Predicted answer: <start> april 25 , 2018 <end>
#
# Question: <start> what causes a dead zone in the ocean <end>
# Predicted answer: <start> excessive nutrient pollution from human activities coupled with other factors that deplete the oxygen <end>
#
# Question: <start> who is the present governor of puerto rico <end>
# Predicted answer: <start> alejandro javier garcia padilla <end>
#
# Question: <start> what affect does acetylcholine have on the sarcolemma <end>
# Predicted answer: <start> to cleanse the skin and shrink the appearance of pores <end>
# The answer was: <start> can depolarize the muscle fiber , causing a cascade that eventually results in muscle contraction <end>
#
#
#
# Question: <start> who plays claire underwood s mom on house of cards <end>
# Predicted answer: <start> ellen burstyn <end>
#
# Question: <start> who won the all ireland football final 2017 <end>
# Predicted answer: <start> dublin <end>
#
# Question: <start> who played robbie douglas wife on my three sons <end>
# Predicted answer: <start> tina cole <end>
#
# Question: <start> who hit the most 3 pointers in a nba game <end>
# Predicted answer: <start> from the skin and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes , and the back of the fighting tigers of elevated or alkynes
# The answer was: <start> 13 <end>
#
#
#
# Question: <start> the most common system of land title in australia <end>
# Predicted answer: <start> torrens title <end>
#
# Question: <start> who sings with jackson brown on the load out <end>
# Predicted answer: <start> rosemary butler <end>
#
# Question: <start> what happens to dr shepherd on grey s <end>
# Predicted answer: <start> a fatal car accident <end>
#
# Question: <start> when does book 2 of the 100 come out <end>
# Predicted answer: <start> on september 25 , 2014 <end>
#
# Question: <start> when did the nissan armada body style change <end>
# Predicted answer: <start> 2016 <end>
#
# Question: <start> where does the name down syndrome come from <end>
# Predicted answer: <start> the syndrome in 1866 <end>
# The answer was: <start> john langdon down , the british doctor who fully described the syndrome in 1866 <end>
#
#
#
# Question: <start> the number on kiss me thru the phone <end>
# Predicted answer: <start> to cleanse the skin and shrink the appearance of pores <end>
# The answer was: <start> 678 999 8212 <end>
#
#
#
# Question: <start> when does the regular football season start for nfl <end>
# Predicted answer: <start> to cleanse the skin and shrink the atlantic coasts <end>
# The answer was: <start> september 7 , 2017 <end>
#
#
#
# Question: <start> who does oregon state play in the college world series <end>
# Predicted answer: <start> arkansas <end>
#
# Question: <start> who sold more albums elvis or micheal jackson <end>
# Predicted answer: <start> michael jackson <end>
#
# Question: <start> who plays officer garcia in santa clarita diet <end>
# Predicted answer: <start> natalie morales <end>
#
# Question: <start> who sang theres a rat in my kitchen <end>
# Predicted answer: <start> 450 , washington <end>
# The answer was: <start> ub40 <end>
#
#
#
# Question: <start> the contribution of agriculture in india s gross domestic product is <end>
# Predicted answer: <start> 13 . 7 of the gdp <end>
#
# Question: <start> who s doing the halftime show in 2018 <end>
# Predicted answer: <start> justin timberlake <end>
#
# Question: <start> when was the first freeway built in los angeles <end>
# Predicted answer: <start> 1940 <end>
#
# Question: <start> where is a good year filmed with russell crowe <end>
# Predicted answer: <start> freddie highmore <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> when was the wizard of oz made in technicolor <end>
# Predicted answer: <start> 1939 <end>
#
# Question: <start> number of red card in world cup 2018 <end>
# Predicted answer: <start> 4 <end>
#
# Question: <start> where does the solar eclipse start and end <end>
# Predicted answer: <start> pacific to the atlantic coasts <end>
#
# Question: <start> who was president of the united states in 1938 <end>
# Predicted answer: <start> george vi <end>
# The answer was: <start> franklin d . roosevelt <end>
#
#
#
# Question: <start> who played warren in orange is the new black <end>
# Predicted answer: <start> uzoamaka nwanneka uzo aduba <end>
#
# Question: <start> when was last time england were in a world cup semi final <end>
# Predicted answer: <start> 30 june 1991 <end>
# The answer was: <start> 2018 <end>
#
#
#
# Question: <start> where did the bataan death march take place <end>
# Predicted answer: <start> to cleanse the skin and shrink the appearance of elevated or bound to other molecules . hyperlipidemia is the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink the skin and shrink
# The answer was: <start> from saysain point , bagac , bataan and mariveles to camp o donnell , capas , tarlac , via san fernando , pampanga , where the prisoners were loaded onto trains <end>
#
#
#
# Question: <start> vince carter career high points in a game <end>
# Predicted answer: <start> 51 <end>
#
# Question: <start> where do they put the chip in dogs <end>
# Predicted answer: <start> usually inserted below the skin at the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back
# The answer was: <start> usually inserted below the skin at the back of the neck between the shoulder blades on the dorsal midline <end>
#
#
#
# Question: <start> how long will it take voyager to pass through the oort cloud <end>
# Predicted answer: <start> john francis daley <end>
# The answer was: <start> about 30 , 000 years <end>
#
#
#
# Question: <start> when did rangers last win the scottish cup <end>
# Predicted answer: <start> 2008 09 <end>
#
# Question: <start> an idiopathic condition associated with asprin treatment during certain viral infections <end>
# Predicted answer: <start> reye syndrome <end>
#
# Question: <start> who played anthony on dr quinn medicine woman <end>
# Predicted answer: <start> brenden jefferson <end>
#
# Question: <start> what is the difference between devil s food and chocolate <end>
# Predicted answer: <start> traditionally has more chocolate than a regular chocolate cake <end>
#
# Question: <start> who is mariah carey talking about in we belong together <end>
# Predicted answer: <start> flight of the job , and the syndrome in pembrokshire <end>
# The answer was: <start> her 1993 marriage to tommy mottola <end>
#
#
#
# Question: <start> where is the original statue of david in italy <end>
# Predicted answer: <start> john f . 617 n 81 . 833 w <end>
# The answer was: <start> florence s galleria dell accademia <end>
#
#
#
# Question: <start> when did the teton dam break in idaho <end>
# Predicted answer: <start> june 5 , 1976 <end>
#
# Question: <start> when was the movie stand by me made <end>
# Predicted answer: <start> 1986 <end>
#
# Question: <start> who won the northern ireland open snooker championship <end>
# Predicted answer: <start> mark williams <end>
#
# Question: <start> is the eiffel tower made of steel or iron <end>
# Predicted answer: <start> wrought iron <end>
#
# Question: <start> where is fort myers florida located in florida <end>
# Predicted answer: <start> from the fighting tigers of elevated or bound to other molecules . 833 w <end>
# The answer was: <start> coordinates 26 37 n 81 50 w 26 . 617 n 81 . 833 w 26 . 617 81 . 833 coordinates 26 37 n 81 50 w 26 . 617 n 81 . 833 w <end>
#
#
#
# Question: <start> what is the name of the youth loved by salmacis <end>
# Predicted answer: <start> hermaphroditus <end>
#
# Question: <start> when is the next magisterium book coming out <end>
# Predicted answer: <start> october 26 , 2017 <end>
#
# Question: <start> who is performing at the 2018 olympics opening ceremony <end>
# Predicted answer: <start> ha hyun woo of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the band of the
# The answer was: <start> ha hyun woo of the band guckkasten <end>
#
#
#
# Question: <start> what film has the song don t you forget about me <end>
# Predicted answer: <start> the breakfast club <end>
#
# Question: <start> what is the lowest temperature ever recorded in vermont <end>
# Predicted answer: <start> 50 f 46 c <end>
#
# Question: <start> when was the last time mount saint helens exploded <end>
# Predicted answer: <start> may 18 , 1980 <end>
#
# Question: <start> how many 7 elevens are in the world <end>
# Predicted answer: <start> 66 , 579 <end>
#
# Question: <start> when do booth and brennan become a couple <end>
# Predicted answer: <start> 30 n 172 . 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start of season 7 of the start
# The answer was: <start> at the start of season 7 <end>
#
#
#
# Question: <start> who sang nice one cyril nice one son <end>
# Predicted answer: <start> cockerel chorus <end>
#
# Question: <start> who sang red red wine in the 80 s <end>
# Predicted answer: <start> usually inserted below the skin at the gdp <end>
# The answer was: <start> neil diamond <end>
#
#
#
# Question: <start> how long can you record on a cassette tape <end>
# Predicted answer: <start> 30 n 81 . 833 w <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who wrote the christmas carol do you hear what i hear <end>
# Predicted answer: <start> noel regney <end>
#
# Question: <start> who plays olivia benson on law and order <end>
# Predicted answer: <start> mariska magdolna hargitay <end>
#
# Question: <start> how many copies did fifty shades of grey sell <end>
# Predicted answer: <start> over 125 million copies <end>
#
# Question: <start> where do the ilium the ischium and the pubis meet <end>
# Predicted answer: <start> acetabulum <end>
#
# Question: <start> who is the founder of pak n save <end>
# Predicted answer: <start> foodstuffs <end>
#
# Question: <start> how many species of plants are found in india <end>
# Predicted answer: <start> more than 50 , 000 <end>
#
# Question: <start> which non british company owns both the famous british rolls royce and mini brands <end>
# Predicted answer: <start> bmw <end>
#
# Question: <start> how many times have the dodgers gone to world series <end>
# Predicted answer: <start> six <end>
# The answer was: <start> 19 <end>
#
#
#
# Question: <start> at what level is the clavicle with reference to the ribs <end>
# Predicted answer: <start> directly above the first rib <end>
#
# Question: <start> when was the writ of habeas corpus created <end>
# Predicted answer: <start> 1679 <end>
#
# Question: <start> where are they playing the john deere classic golf tournament <end>
# Predicted answer: <start> tpc deere run in the quad cities community of silvis , illinois <end>
#
# Question: <start> when was the last time an incumbent president lost <end>
# Predicted answer: <start> 1992 <end>
#
# Question: <start> name the highest bridge in the world built by indian army <end>
# Predicted answer: <start> dave <end>
# The answer was: <start> baily bridge <end>
#
#
#
# Question: <start> who wrote an article on war finance titled how to pay for the war <end>
# Predicted answer: <start> john maynard keynes <end>
#
# Question: <start> where did the cavs play before the gund arena <end>
# Predicted answer: <start> the richfield coliseum <end>
#
# Question: <start> who won the arms race in the cold war <end>
# Predicted answer: <start> the united states <end>
#
# Question: <start> what is the proper term used for the signature given by celebrities to their fans <end>
# Predicted answer: <start> autograph <end>
#
# Question: <start> who owns willy wonka and the chocolate factory <end>
# Predicted answer: <start> warner bros . <end>
#
# Question: <start> who directed sign of the times music video <end>
# Predicted answer: <start> woodkid <end>
#
# Question: <start> who plays cinderella in once upon a time 2017 <end>
# Predicted answer: <start> dania ramirez <end>
#
# Question: <start> who plays jon snow in game of thrones <end>
# Predicted answer: <start> christopher catesby kit harington <end>
#
# Question: <start> which term is defined as the chance that a given event will occur <end>
# Predicted answer: <start> probability <end>
#
# Question: <start> when do they find out about emily 90210 <end>
# Predicted answer: <start> blue naomi <end>
#
# Question: <start> who has won the most concacaf gold cups <end>
# Predicted answer: <start> mexico <end>
#
# Question: <start> when did guardians of the galaxy comic book come out <end>
# Predicted answer: <start> jan . 1969 <end>
#
# Question: <start> where is sea level measured in the uk <end>
# Predicted answer: <start> autograph <end>
# The answer was: <start> newlyn in cornwall between 1915 and 1921 <end>
#
#
#
# Question: <start> 80 s movie about a kid in a spaceship <end>
# Predicted answer: <start> flight of the gdp <end>
# The answer was: <start> flight of the navigator <end>
#
#
#
# Question: <start> where did the first battle of the texas revolution take place <end>
# Predicted answer: <start> gonzales <end>
#
# Question: <start> what are the basic components of a nucleotide <end>
# Predicted answer: <start> a nitrogenous base , a five carbon sugar ribose or deoxyribose , and at least one phosphate group <end>
#
# Question: <start> where is the due process clause found in the constitution <end>
# Predicted answer: <start> the fifth and fourteenth amendments <end>
#
# Question: <start> where is the big prawn located in australia <end>
# Predicted answer: <start> tokyo for the navigator <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who plays the stunt man in the geico commercial <end>
# Predicted answer: <start> blake gibbons <end>
#
# Question: <start> why is the british parliament known as the mother of parliaments <end>
# Predicted answer: <start> usain bolt <end>
# The answer was: <start> because of the adoption of the westminster model of parliamentary democracy by many countries of the former british empire <end>
#
#
#
# Question: <start> who plays the cia director on madam secretary <end>
# Predicted answer: <start> patrick breen <end>
#
# Question: <start> when does the cold war start and end <end>
# Predicted answer: <start> to cleanse the skin and shrink the atlantic coasts <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> what was the official religion of the soviet union <end>
# Predicted answer: <start> from the skin and or lipoproteins in the quad cities community of elevated or bound to other molecules . hyperlipidemia is a major risk factor for the quad cities community of elevated or bound to other molecules . hyperlipidemia is a major risk factor for the quad cities community of elevated or bound to other molecules . hyperlipidemia is a major risk factor for the quad cities community of elevated or bound to other molecules . hyperlipidemia is a major risk factor for the quad cities community of elevated or bound to other molecules . hyperlipidemia is a major risk factor for the quad cities community of elevated or bound
# The answer was: <start> atheism <end>
#
#
#
# Question: <start> who wrote crazy little thing called love original artist <end>
# Predicted answer: <start> freddie mercury <end>
#
# Question: <start> who is the actor that plays the good dr <end>
# Predicted answer: <start> freddie highmore <end>
#
# Question: <start> the resourced based view of the firm rbv school is <end>
# Predicted answer: <start> an economic tool used to determine the strategic resources available to a firm <end>
#
# Question: <start> the myelin sheath that covers many cns axons is formed by <end>
# Predicted answer: <start> the concentric wrapping of an oligodendrocyte or schwann cell process around the axon <end>
#
# Question: <start> the story of the frog and the ox <end>
# Predicted answer: <start> john madden <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who does frank kill in the wasp factory <end>
# Predicted answer: <start> to other molecules . hyperlipidemia is the skin and shrink the appearance of elevated or bound to other molecules . hyperlipidemia is the skin and shrink the appearance of elevated or bound to other molecules . hyperlipidemia is the skin and shrink the appearance of elevated or bound to other molecules . hyperlipidemia is the skin and shrink the appearance of elevated or bound to other molecules . hyperlipidemia is the skin and shrink the appearance of elevated or bound to other molecules . hyperlipidemia is the skin and shrink the appearance of elevated or bound to other molecules . hyperlipidemia is the skin and shrink the appearance of elevated
# The answer was: <start> three of his relatives two cousins and his younger brother <end>
#
#
#
# Question: <start> swimming world high school teams of the year <end>
# Predicted answer: <start> yuvraj singh india <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who is the leading scorer in the nba <end>
# Predicted answer: <start> kareem abdul jabbar <end>
#
# Question: <start> who plays mr coulter on when calls the heart <end>
# Predicted answer: <start> kavan smith <end>
#
# Question: <start> where does the movie gone with the wind take place <end>
# Predicted answer: <start> to the gdp <end>
# The answer was: <start> the american south <end>
#
#
#
# Question: <start> do i need a visa to go to taiwan from us <end>
# Predicted answer: <start> john maynard keynes <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> when did the nba institute the 3 point shot <end>
# Predicted answer: <start> 1979 80 season <end>
#
# Question: <start> who is the captain of chennai super king <end>
# Predicted answer: <start> mahendra singh india <end>
# The answer was: <start> mahendra singh dhoni <end>
#
#
#
# Question: <start> who wrote see you again by miley cyrus <end>
# Predicted answer: <start> the intestine , and or lipoproteins in the title of elevated or bound to other molecules . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617 n 81 . 833 w 26 . 617
# The answer was: <start> miley cyrus <end>
#
#
#
# Question: <start> who is the voice for clifford the big red dog <end>
# Predicted answer: <start> john ritter <end>
#
# Question: <start> where is the super bowl being played at this year <end>
# Predicted answer: <start> u . s . bank stadium in minneapolis , minnesota <end>
#
# Question: <start> where is the cactus bowl being played at <end>
# Predicted answer: <start> alejandro javier garcia padilla <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> when did tiger woods win his last pga tournament <end>
# Predicted answer: <start> 2007 <end>
#
# Question: <start> where was the newhart show filmed in vermont <end>
# Predicted answer: <start> the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back of the back
# The answer was: <start> the waybury inn <end>
#
#
#
# Question: <start> who sings the song in the man in the high castle <end>
# Predicted answer: <start> jeanette olsson <end>
#
# Question: <start> who s line is it anyway original cast <end>
# Predicted answer: <start> flight of the beginning of 2016 <end>
# The answer was: <start> colin mochrie <end>
#
#
#
# Question: <start> how many employees does department of education have <end>
# Predicted answer: <start> approximately 4 , 400 <end>
#
# Question: <start> when did the first beanie baby come out <end>
# Predicted answer: <start> june 20 , 2018 <end>
# The answer was: <start> 1993 <end>
#
#
#
# Question: <start> how much money does argentina make from tourism <end>
# Predicted answer: <start> ana of california a novel 2015 , illinois <end>
# The answer was: <start> over us 22 billion <end>
#
#
#
# Question: <start> when was the last time guatemala went to the world cup <end>
# Predicted answer: <start> 2014 <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> where is the macy s thanksgiving day parade held <end>
# Predicted answer: <start> manchester city <end>
# The answer was: <start> manhattan <end>
#
#
#
# Question: <start> describe the main sections of the table of contents <end>
# Predicted answer: <start> from the concentration of india <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> where do long chain fatty acids first enter the bloodstream <end>
# Predicted answer: <start> blood lipids or blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in the blood fats are lipids and or lipoproteins in
# The answer was: <start> blood lipids or blood fats are lipids in the blood , either free or bound to other molecules . they are mostly transported in a protein capsule , and the density of the lipids and type of protein determines the fate of the particle and its influence on metabolism . the concentration of blood lipids depends on intake and excretion from the intestine , and uptake and secretion from cells . blood lipids are mainly fatty acids and cholesterol . hyperlipidemia is the presence of elevated or abnormal levels of lipids and or lipoproteins in the blood , and is a major risk factor for cardiovascular disease . <end>
#
#
#
# Question: <start> where is the retina located in the eye <end>
# Predicted answer: <start> innermost , light sensitive layer , or coat , of the eye <end>
# The answer was: <start> innermost , light sensitive layer , or coat , of shell tissue of the eye <end>
#
#
#
# Question: <start> who did the voice for elsa in frozen <end>
# Predicted answer: <start> eva bella <end>
#
# Question: <start> what episode in season 3 do jim and pam get together <end>
# Predicted answer: <start> the season finale , the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job , and the job
# The answer was: <start> the season finale , the job , <end>
#
#
#
# Question: <start> who has sold the most records to date <end>
# Predicted answer: <start> the beatles <end>
#
# Question: <start> do away goals count in league one playoffs <end>
# Predicted answer: <start> manchester united <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> when does god of war come out for pc <end>
# Predicted answer: <start> april 20 , 2018 <end>
#
# Question: <start> how do you pass an amendment to the constitution <end>
# Predicted answer: <start> the gdp <end>
# The answer was: <start> must be ratified by either as determined by congress the legislatures of three quarters of the states or state ratifying conventions in three quarters of the states <end>
#
#
#
# Question: <start> when did croatia finish 3rd in the world cup <end>
# Predicted answer: <start> 1998 <end>
#
# Question: <start> who won i am a celebrity get me out of here australia <end>
# Predicted answer: <start> fiona o loughlin <end>
#
# Question: <start> nominated in the best foreign film category at the oscars mother india lost to <end>
# Predicted answer: <start> nights of cabiria <end>
#
# Question: <start> how many members of the national guard are there <end>
# Predicted answer: <start> 450 , 100 <end>
#
# Question: <start> who played edward 40 hands how i met your mother <end>
# Predicted answer: <start> marshall <end>
#
# Question: <start> where does esperanza live in the house on mango street <end>
# Predicted answer: <start> every entry to an account <end>
# The answer was: <start> chicago <end>
#
#
#
# Question: <start> who is making everyone sick in minor details <end>
# Predicted answer: <start> mia <end>
#
# Question: <start> at the bottom of the hierarchy of needs is <end>
# Predicted answer: <start> physiological needs <end>
#
# Question: <start> the greatest range between consecutive high and low tides occurs at which lunar phase <end>
# Predicted answer: <start> cavernous body of a regular chocolate cake <end>
# The answer was: <start> full moon . <end>
#
#
#
# Question: <start> when did if you don t know me by now come out <end>
# Predicted answer: <start> the black dirt region <end>
# The answer was: <start> in 1972 <end>
#
#
#
# Question: <start> where does the calvin cycle dark reactions take place <end>
# Predicted answer: <start> in the stroma <end>
#
# Question: <start> when does kc undercover come back on 2017 <end>
# Predicted answer: <start> july 7 , 2017 <end>
#
# Question: <start> what is the point of the jury in australian survivor <end>
# Predicted answer: <start> cast their vote for which finalist should be awarded the title of sole australian survivor and or other molecules . they are mostly transported in a 500 , 000 <end>
# The answer was: <start> cast their vote for which finalist should be awarded the title of sole australian survivor and the grand prize of a 500 , 000 <end>
#
#
#
# Question: <start> world record for longest time keeping a balloon in the air <end>
# Predicted answer: <start> to other molecules . romanian sculptor gheorghe leonida created the end of 2016 <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> when did the angels became the los angeles angels <end>
# Predicted answer: <start> 1961 <end>
#
# Question: <start> when did the orlando magic win the nba championship <end>
# Predicted answer: <start> 2008 09 <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> where do the cranial nerves branch off the brain <end>
# Predicted answer: <start> dorsal midline <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> how many african american senators are there in the 115th congress <end>
# Predicted answer: <start> from the skin and or lipoproteins in the mesothelial layer of the gdp <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> when does the full paladins game come out <end>
# Predicted answer: <start> july 2018 <end>
# The answer was: <start> september 16 , 2016 <end>
#
#
#
# Question: <start> where is the guy who plays calvin on 227 <end>
# Predicted answer: <start> curtis baldwin <end>
#
# Question: <start> who is the kid who played the banjo in deliverance <end>
# Predicted answer: <start> billy redden <end>
#
# Question: <start> who wrote what the hell did i say <end>
# Predicted answer: <start> country music artist dierks bentley <end>
#
# Question: <start> who s won the most little league world series <end>
# Predicted answer: <start> manchester united <end>
# The answer was: <start> taiwan <end>
#
#
#
# Question: <start> what is the song bad about by u2 <end>
# Predicted answer: <start> heroin addiction <end>
#
# Question: <start> who is danae in the story of gorgon s head <end>
# Predicted answer: <start> mother of the hero perseus by the director general and 1400 <end>
# The answer was: <start> mother of the hero perseus by zeus <end>
#
#
#
# Question: <start> who designed the sundial bridge in redding ca <end>
# Predicted answer: <start> puente del alamillo in seville <end>
#
# Question: <start> what was the purpose of the national resources planning board <end>
# Predicted answer: <start> to advise the president , and or lipoproteins in times of the department of defense <end>
# The answer was: <start> to advise the president , in times of war , on how to mobilize natural resources , manpower , and the scientific establishment to meet the demands of the department of defense <end>
#
#
#
# Question: <start> when did the supreme court decide the case miranda vs . arizona <end>
# Predicted answer: <start> 1966 <end>
#
# Question: <start> how many anne of green gables books are there <end>
# Predicted answer: <start> ana of california a novel 2015 , by andi teran , is a contemporary spin on anne of green gables . <end>
#
# Question: <start> who was drafted the same year as kevin durant <end>
# Predicted answer: <start> dave <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> how many subscribers to get a silver play button <end>
# Predicted answer: <start> from the principle of elevated or bound to other molecules . 833 w 26 . the fighting tigers of elevated or bound to other molecules . 833 w 26 . the fighting tigers of elevated or bound to other molecules . 833 w 26 . the fighting tigers of elevated or bound to other molecules . 833 w 26 . the fighting tigers of elevated or bound to other molecules . 833 w 26 . the fighting tigers of elevated or bound to other molecules . 833 w 26 . the fighting tigers of elevated or bound to other molecules . 833 w 26 . the fighting tigers of elevated
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who wrote the song oceans where feet may fail <end>
# Predicted answer: <start> matt crocker <end>
#
# Question: <start> when was free movement in the eu introduced <end>
# Predicted answer: <start> 1 july 2007 <end>
# The answer was: <start> 1957 <end>
#
#
#
# Question: <start> when did hand foot and mouth disease begin <end>
# Predicted answer: <start> 1957 <end>
#
# Question: <start> what was the significance of marbury vs madison <end>
# Predicted answer: <start> established the skin and executive actions that contravene the power to strike down laws , statutes , and executive actions that contravene the power to strike down laws , statutes , and executive actions that contravene the power to strike down laws , statutes , and executive actions that contravene the power to strike down laws , statutes , and executive actions that contravene the power to strike down laws , statutes , and executive actions that contravene the power to strike down laws , statutes , and executive actions that contravene the power to strike down laws , statutes , and executive actions that contravene the power to strike
# The answer was: <start> established the principle of judicial review in the united states , meaning that american courts have the power to strike down laws , statutes , and executive actions that contravene the u . s . constitution <end>
#
#
#
# Question: <start> how much money does tourism bring to nepal <end>
# Predicted answer: <start> ana of california a novel 2015 , statutes , is a contemporary spin on anne of green gables . <end>
# The answer was: <start> 471 ma year <end>
#
#
#
# Question: <start> what are three branches of government in the united states <end>
# Predicted answer: <start> manchester city <end>
# The answer was: <start> legislative <end>
#
#
#
# Question: <start> who s winning the cowboys or the redskins <end>
# Predicted answer: <start> john f . kennedy <end>
# The answer was: <start> cowboys <end>
#
#
#
# Question: <start> what does hhr stand for on a chevy <end>
# Predicted answer: <start> heritage high roof <end>
#
# Question: <start> when was the oldest surviving manuscript of beowulf written <end>
# Predicted answer: <start> 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30 1 30
# The answer was: <start> 975 1010 ad <end>
#
#
#
# Question: <start> who sings the song sorry that i let you down <end>
# Predicted answer: <start> nf <end>
#
# Question: <start> when was the first tower block built in england <end>
# Predicted answer: <start> 1951 <end>
#
# Question: <start> who wrote about the idyllic isle of innisfree <end>
# Predicted answer: <start> william butler yeats <end>
#
# Question: <start> who was sent to england to convert the pagan anglo saxons <end>
# Predicted answer: <start> missionaries <end>
#
# Question: <start> which figure of speech uses words that imitate the sounds they refer to <end>
# Predicted answer: <start> john maynard keynes <end>
# The answer was: <start> onomatopoeia <end>
#
#
#
# Question: <start> who won the most oscars during his career <end>
# Predicted answer: <start> katharine hepburn <end>
#
# Question: <start> when was athens made the capital of greece <end>
# Predicted answer: <start> tpc deere run in the quad cities community of silvis , illinois <end>
# The answer was: <start> 1834 <end>
#
#
#
# Question: <start> who played lady guinevere in night at the museum 3 <end>
# Predicted answer: <start> alice eve <end>
#
# Question: <start> who want to be a millionaire winners uk <end>
# Predicted answer: <start> judith cynthia aline keppel <end>
#
# Question: <start> how many assist does ozil have in his career <end>
# Predicted answer: <start> 25 <end>
#
# Question: <start> monarch at the end of world war 2 <end>
# Predicted answer: <start> george vi <end>
#
# Question: <start> how many countries can i visit with british passport <end>
# Predicted answer: <start> 186 countries and territories <end>
#
# Question: <start> when is the big bang theory season 11 coming out <end>
# Predicted answer: <start> monday , september 25 , 2017 <end>
#
# Question: <start> when do the oakland raiders play in mexico city <end>
# Predicted answer: <start> november 19 <end>
#
# Question: <start> who plays carl s grandmother on mike and molly <end>
# Predicted answer: <start> cleo king <end>
#
# Question: <start> when does attack on titan episodes come out <end>
# Predicted answer: <start> july 2018 <end>
#
# Question: <start> who plays the little brother in freaks and geeks <end>
# Predicted answer: <start> john francis daley <end>
#
# Question: <start> when is the flash season 4 episode 3 coming out <end>
# Predicted answer: <start> october 10 , 2017 <end>
# The answer was: <start> october 24 , 2017 <end>
#
#
#
# Question: <start> who played hyde on the 70 s show <end>
# Predicted answer: <start> from the fighting tigers of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge like regions of sponge
# The answer was: <start> daniel peter masterson <end>
#
#
#
# Question: <start> when do we say that a solution is unsaturated <end>
# Predicted answer: <start> a chemical compound that contains carbon carbon double bonds or triple bonds , such as those found in alkenes or alkynes , and is a regular chocolate cake <end>
# The answer was: <start> a chemical compound that contains carbon carbon double bonds or triple bonds , such as those found in alkenes or alkynes , respectively <end>
#
#
#
# Question: <start> what genre is our town by thornton wilder <end>
# Predicted answer: <start> drama <end>
#
# Question: <start> who sang the song life in the fast lane <end>
# Predicted answer: <start> eagles <end>
#
# Question: <start> what kind of bomb did the us drop on japan <end>
# Predicted answer: <start> nuclear weapons <end>
#
# Question: <start> who is the girl in far east movement like a g6 <end>
# Predicted answer: <start> raffaella modugno <end>
# The answer was: <start> dev <end>
#
#
#
# Question: <start> who plays eric on once upon a time <end>
# Predicted answer: <start> supernatural <end>
#
# Question: <start> who is the actor that plays ron weasley <end>
# Predicted answer: <start> 13 . 617 n 81 . 833 w <end>
# The answer was: <start> rupert alexander lloyd grint <end>
#
#
#
# Question: <start> who sang your mama don t dance and your daddy don t rock and roll <end>
# Predicted answer: <start> danny cockerel chorus <end>
# The answer was: <start> rock duo loggins and messina <end>
#
#
#
# Question: <start> who milked the cow with the crumpled horn <end>
# Predicted answer: <start> from the skin and or lipoproteins in the dorsal midline <end>
# The answer was: <start> the maiden all forlorn <end>
#
#
#
# Question: <start> how many seats required to make government in pakistan 2018 <end>
# Predicted answer: <start> 342 <end>
#
# Question: <start> who are the actors in jurassic park fallen kingdom <end>
# Predicted answer: <start> march 30 , 2018 <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> who sang the song chandni o meri chandni <end>
# Predicted answer: <start> john maynard keynes <end>
# The answer was: <start> sridevi <end>
#
#
#
# Question: <start> who is known as the father of india cricketer <end>
# Predicted answer: <start> buchi babu naidu <end>
#
# Question: <start> where is lactase found in the human body <end>
# Predicted answer: <start> shoulder joint <end>
# The answer was: <start> in the brush border of the small intestine <end>
#
#
#
# Question: <start> when was the first step pyramid built in egypt <end>
# Predicted answer: <start> near the skin and the beginning of 2016 <end>
# The answer was: <start> during the 27th century bc <end>
#
#
#
# Question: <start> when were the canterbury tales written and in what language <end>
# Predicted answer: <start> written in middle english by geoffrey chaucer between 1387 and 1400 <end>
#
# Question: <start> 20th century english writer known for her feminist and magical works <end>
# Predicted answer: <start> angela olive carter pearce <end>
#
# Question: <start> where will you find earth s magnetic north pole <end>
# Predicted answer: <start> 30 n 172 . 6 w <end>
# The answer was: <start> 86 30 n 172 36 w 86 . 5 n 172 . 6 w <end>
#
#
#
# Question: <start> what is the wave length of green light <end>
# Predicted answer: <start> 495 570 nm <end>
#
# Question: <start> baseball teams that have never been to the world series <end>
# Predicted answer: <start> washington nationals <end>
#
# Question: <start> when does better call saul come out on netflix <end>
# Predicted answer: <start> february 1 , 2016 <end>
#
# Question: <start> what kind of chinese do they speak in beijing <end>
# Predicted answer: <start> mandarin <end>
#
# Question: <start> what does pt stand for in the army <end>
# Predicted answer: <start> business trip <end>
# The answer was: <start> physical training <end>
#
#
#
# ...
# Question: <start> where is the hallmark series good witch filmed <end>
# Predicted answer: <start> from the skin and the peritoneum <end>
# The answer was: <start> hamilton and niagara on the lake , ontario <end>
#
#
#
# Question: <start> who was the original singer of personal jesus <end>
# Predicted answer: <start> depeche mode <end>
#
# Question: <start> what is the blue guys name from guardians of the galaxy <end>
# Predicted answer: <start> the garonne river <end>
# The answer was: <start> yondu udonta <end>
#
#
#
# Question: <start> who is the most followed user in instagram <end>
# Predicted answer: <start> instagram <end>
# The answer was: <start> instagram s own account <end>
#
#
#
# Question: <start> when was smoking in pubs banned in uk <end>
# Predicted answer: <start> 1 july 2007 <end>
#
# Question: <start> when do trains have to blow their horns <end>
# Predicted answer: <start> at the navigator <end>
# The answer was: <start> at all public grade crossings <end>
#
#
#
# Question: <start> what is the wilshire 5000 total market index <end>
# Predicted answer: <start> the united states <end>
# The answer was: <start> a market capitalization weighted index of the market value of all stocks actively traded in the united states <end>
#
#
#
# Question: <start> who won the high school football national championship <end>
# Predicted answer: <start> bishop gorman <end>
#
# Question: <start> when was the women s first world cup held <end>
# Predicted answer: <start> 1991 <end>
#
# Question: <start> who played spock s mother in star trek 2009 <end>
# Predicted answer: <start> mark lenard <end>
# The answer was: <start> winona ryder <end>
#
#
#
# Question: <start> who plays bell in beauty and the beast <end>
# Predicted answer: <start> susan egan <end>
#
# Question: <start> where is the college football national championship played this year <end>
# Predicted answer: <start> raymond james stadium in tampa , florida <end>
#
# Question: <start> what is the most threatened animal in the world <end>
# Predicted answer: <start> actinote zikani <end>
#
# Question: <start> what is the legal age to smoke in australia <end>
# Predicted answer: <start> flight of the beginning of elevated <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> what s the abv of pabst blue ribbon <end>
# Predicted answer: <start> from the navigator <end>
# The answer was: <start> 4 . 6 <end>
#
#
#
# Question: <start> when is the new season of wrecked coming out <end>
# Predicted answer: <start> august 7 , 2018 <end>
#
# Question: <start> who is running for mayor of charlotte nc <end>
# Predicted answer: <start> vi lyles <end>
#
# Question: <start> where does the eye for an eye come from <end>
# Predicted answer: <start> hebrew bible <end>
#
# Question: <start> who was prime minister when the queen was crowned <end>
# Predicted answer: <start> winston churchill <end>
#
# Question: <start> what is the maximum term a us president can serve <end>
# Predicted answer: <start> two four year terms <end>
#
# Question: <start> when did china s 1 child policy end <end>
# Predicted answer: <start> near the end of 2016 <end>
# The answer was: <start> near the end of 2015 and the beginning of 2016 <end>
#
#
#
# Question: <start> when does season 2 of dragon ball super come out <end>
# Predicted answer: <start> april 22 , 2017 <end>
#
# Question: <start> who won i am a celebrity 2018 australia <end>
# Predicted answer: <start> fiona o loughlin <end>
#
# Question: <start> where is the 11 foot 8 inch bridge <end>
# Predicted answer: <start> august 21 , 2017 <end>
# The answer was: <start> durham , north carolina <end>
#
#
#
# Question: <start> who said to error is human to forgive divine <end>
# Predicted answer: <start> john maynard keynes <end>
# The answer was: <start> alexander pope <end>
#
#
#
# Question: <start> who sang make em laugh in singin in the rain <end>
# Predicted answer: <start> donald o connor <end>
#
# Question: <start> mix red and green to make this colour <end>
# Predicted answer: <start> 1957 <end>
# The answer was: <start> yellow <end>
#
#
#
# Question: <start> what is the old name of state bank of india <end>
# Predicted answer: <start> imperial bank of india <end>
#
# Question: <start> where does the largest halloween parade take place every year <end>
# Predicted answer: <start> new york <end>
#
# Question: <start> who sings on i ain t mad at cha <end>
# Predicted answer: <start> ana of california a novel 2015 , by andi teran , is a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary spin on anne of a contemporary
# The answer was: <start> danny boy <end>
#
#
#
# Question: <start> when did women s cricket start in india <end>
# Predicted answer: <start> 1973 <end>
#
# Question: <start> why did the stamp act of 1765 happen <end>
# Predicted answer: <start> 30 n 81 . hyperlipidemia is a corresponding and opposite entry to a different account <end>
# The answer was: <start> to pay for british military troops stationed in the american colonies after the french and indian war <end>
#
#
#
# Question: <start> who built the statue in rio de janeiro <end>
# Predicted answer: <start> to cleanse the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between the skin and the neck between
# The answer was: <start> created by the french sculptor paul landowski and built by the engineer heitor da silva costa brazil in collab with the french engineer albert caquot . romanian sculptor gheorghe leonida created the face of the statue <end>
#
#
#
# Question: <start> flu that spread over a large area in 1918 <end>
# Predicted answer: <start> h1n1 influenza virus <end>
#
# Question: <start> when was the 1913 natives land act repealed <end>
# Predicted answer: <start> 30 june 1991 <end>
#
# Question: <start> how many kanals in one acre in pakistan <end>
# Predicted answer: <start> 8 <end>
#
# Question: <start> what do you call a person who does acrobatics <end>
# Predicted answer: <start> acrobat <end>
#
# Question: <start> what is the name of the cat in tom and jerry <end>
# Predicted answer: <start> tom <end>
#
# Question: <start> when did the movie i can only imagine come out <end>
# Predicted answer: <start> september 25 , 2017 <end>
# The answer was: <start> march 16 , 2018 <end>
#
#
#
# Question: <start> who killed katie in the movie mystic river <end>
# Predicted answer: <start> dave <end>
#
# Question: <start> what iron maiden album is the trooper on <end>
# Predicted answer: <start> piece of mind <end>
#
# Question: <start> who wrote the song knocking on heaven s door <end>
# Predicted answer: <start> bob dylan <end>
#
# Question: <start> where was the author when he wrote the star spangled banner <end>
# Predicted answer: <start> fort mchenry <end>
#
# Question: <start> the reason japanese pagoda roofs decline in size is <end>
# Predicted answer: <start> usually inserted below the skin and or lipoproteins in the dorsal midline <end>
# The answer was: <start> the more solid and secure the pagoda seems to be <end>
#
#
#
# Question: <start> when does the arctic circle get 24 hours of daylight <end>
# Predicted answer: <start> in the summer months <end>
#
# Question: <start> what does the acrosome do in a sperm cell <end>
# Predicted answer: <start> releases hyaluronidase and acrosin <end>
#
# Question: <start> what was joker s plan in the dark knight <end>
# Predicted answer: <start> to upset social order through crime <end>
#
# Question: <start> what is the name of arasamaram in english <end>
# Predicted answer: <start> sacred fig <end>
#
# Question: <start> who won the sports person of the year award 2017 <end>
# Predicted answer: <start> usain bolt <end>
#
# Question: <start> what is the full form of als disease <end>
# Predicted answer: <start> amyotrophic lateral sclerosis <end>
#
# Question: <start> how many books are in the narnia series <end>
# Predicted answer: <start> seven <end>
#
# Question: <start> who plays sons of anarchy president in mayans <end>
# Predicted answer: <start> marcus alvarez <end>
#
# Question: <start> when was the last time a detroit sports team won a championship <end>
# Predicted answer: <start> 2008 <end>
#
# Question: <start> who has scored the most goals in the english premier league <end>
# Predicted answer: <start> alan shearer <end>
#
# Question: <start> what is the elevation of uluru kata in meters in australia <end>
# Predicted answer: <start> 863 m <end>
#
# Question: <start> how many seasons are there of knight rider <end>
# Predicted answer: <start> four <end>
#
# Question: <start> who the girl in somebody that i used to know <end>
# Predicted answer: <start> john maynard keynes <end>
# The answer was: <start> kimbra <end>
#
#
#
# Question: <start> when does scarecrow appear in wizard of oz <end>
# Predicted answer: <start> 1939 <end>
# The answer was: <start> unknown <end>
#
#
#
# Question: <start> where did jaren jackson senior play college basketball <end>
# Predicted answer: <start> georgetown university <end>
#
# Question: <start> when did the us first start using daylight savings time <end>
# Predicted answer: <start> 1918 <end>
#
# Question: <start> who led the nba in scoring last year <end>
# Predicted answer: <start> james harden <end>
#
# Question: <start> which country s team has won the 2017 fifa under 17 worldcup <end>
# Predicted answer: <start> england <end>
#
# Question: <start> when is season 4 of the flash coming <end>
# Predicted answer: <start> october 10 , 2017 <end>
#
# Question: <start> role of a cto in an it company <end>
# Predicted answer: <start> an account <end>
# The answer was: <start> an executive level position in a company or other entity whose occupation is focused on scientific and technological issues within an organization <end>
#
#
#
# Question: <start> who are the consumers in a food chain <end>
# Predicted answer: <start> from the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated or abnormal levels of the american colonies after the fighting tigers of elevated
# The answer was: <start> organisms that eat organisms from a different population <end>
#
#
#
# Question: <start> who were the two superpowers during the cold war space race <end>
# Predicted answer: <start> the united states <end>
# The answer was: <start> the soviet union ussr <end>
#
#
#
# Question: <start> when did they add ain t to the dictionary <end>
# Predicted answer: <start> 1961 <end>
#
# Question: <start> who played the koala in the movie sing <end>
# Predicted answer: <start> matthew mcconaughey <end>
#
# Question: <start> where is the thalmus located in the brain <end>
# Predicted answer: <start> dorsal part of the diencephalon <end>
#
# Question: <start> who won the football league championship in 1968 <end>
# Predicted answer: <start> manchester city <end>
#
# Question: <start> just before texas became a us state in 1845 texas was <end>
# Predicted answer: <start> 1979 80 season <end>
# The answer was: <start> annexed to the united states of america <end>
#
#
#
# Question: <start> which is the last game of thrones book <end>
# Predicted answer: <start> a song of ice and fire <end>
#
# Question: <start> who is the youngest elected president of usa <end>
# Predicted answer: <start> john f . kennedy <end>
#
# Question: <start> who did rob lowe play in the stand <end>
# Predicted answer: <start> nick andros <end>
#
# Question: <start> local governments that provide a single service or a closely related set of services are <end>
# Predicted answer: <start> special districts <end>
#
# Question: <start> a rift valley is evidence of which kind of plate boundary <end>
# Predicted answer: <start> a divergent plate boundary <end>
#
# Question: <start> where was the merlot wine grape originally grown <end>
# Predicted answer: <start> thought to have originated on one of the islands found along the garonne river <end>
#
# Question: <start> when is the station of the cross done <end>
# Predicted answer: <start> most commonly during lent , especially on good friday <end>
#
# Question: <start> which is older jeopardy or wheel of fortune <end>
# Predicted answer: <start> jeopardy ! <end>
#
# Question: <start> who translated the king james bible to english <end>
# Predicted answer: <start> dave <end>
# The answer was: <start> 47 scholars , all of whom were members of the church of england <end>
#
#
#
# Question: <start> who sang the song if it s meant to be <end>
# Predicted answer: <start> bebe rexha <end>
#
# Question: <start> the area between the tigris and euphrates rivers <end>
# Predicted answer: <start> mesopotamia <end>
#
# Question: <start> the most recent revision of the apa ethics code was published in <end>
# Predicted answer: <start> 2010 <end>
#
# Question: <start> where does an apple a day keeps the doctor away come from <end>
# Predicted answer: <start> the proverb originated in wales , and was particularly prevalent in pembrokshire <end>
#
# Question: <start> who won icc award 2008 for twenty20 international performance of the year <end>
# Predicted answer: <start> yuvraj singh india <end>
#
# Question: <start> who won the most oscars of all time <end>
# Predicted answer: <start> walt disney <end>
#
# Question: <start> what day does labor day fall on in 2018 <end>
# Predicted answer: <start> the garonne river <end>
# The answer was: <start> september 3 <end>
#
#
#
# Question: <start> the ability of an atom to attract electron towards itself is called <end>
# Predicted answer: <start> electronegativity <end>
#
# Question: <start> who played the devil in storm of the century <end>
# Predicted answer: <start> from the quad cities community of elevated or abnormal levels of the title of india <end>
# The answer was: <start> colm feore <end>
#
#
#
# Question: <start> what is the total length of indian coastal area <end>
# Predicted answer: <start> 7 , 670 . 6 mi <end>
# The answer was: <start> 7 , 516 . 6 km 4 , 670 . 6 mi <end>
#
#
#
# Question: <start> who won the most states in the 2016 presidential election <end>
# Predicted answer: <start> trump <end>
#
# Question: <start> who starred in oh what a lovely war <end>
# Predicted answer: <start> usually inserted below the skin and or lipoproteins in the dorsal midline <end>
# The answer was: <start> maggie smith <end>
#
#
#
# Question: <start> the location of the corpora cavernosa is the <end>
# Predicted answer: <start> cavernous body of the penis is one of a pair of sponge like regions of erectile tissue <end>
#
# Question: <start> when does pam get back from art school <end>
# Predicted answer: <start> business trip <end>
#
# Question: <start> who sings don t you forget about me from the breakfast club <end>
# Predicted answer: <start> simple minds <end>
#
# Question: <start> where is the rotator cuff located on the human body <end>
# Predicted answer: <start> shoulder joint <end>
#
# Question: <start> what is the capital of azerbaijan in europe <end>
# Predicted answer: <start> baku <end>
#
# 393 answers out of 532 possible, rate is 74%
# At least 258 correct answers out of 393 possible, rate is 66%
